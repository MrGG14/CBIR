# %%
import tensorflow as tf
import numpy as np
import cv2
import matplotlib.pyplot as plt
import os
import random

# %%
n_imgs = 100
carpetas = ["autobus-n04487081", "clavos-n03804744", "coche-n02814533", "collarin-n03814639", "desatascador-n03970156",
            "esponja_mar-n01917289", "gatos-n02123394", "mono-n02480495", "puentes-n04532670", "silla-n04099969"]

# %%
def get_images_path(carpetas, n_imgs):
    images_path = {}
    for carpeta in carpetas:
        for i in range(n_imgs):
            images_path[(carpeta[-7:], str(i))] = f'./dataset/{carpeta}/{carpeta[-9:]}_{str(i)}.JPEG'
    return images_path #Devuelve un diccionario en el que la clave es (carpeta, id), y los valores los paths

# %%
images_path = get_images_path(carpetas, n_imgs)
len(images_path)
# Out:
# 1000

# %%
images_path
# Out:
# {('4487081', '0'): './dataset/autobus-n04487081/n04487081_0.JPEG',
#  ('4487081', '1'): './dataset/autobus-n04487081/n04487081_1.JPEG',
#  ('4487081', '2'): './dataset/autobus-n04487081/n04487081_2.JPEG',
#  ('4487081', '3'): './dataset/autobus-n04487081/n04487081_3.JPEG',
#  ('4487081', '4'): './dataset/autobus-n04487081/n04487081_4.JPEG',
#  ('4487081', '5'): './dataset/autobus-n04487081/n04487081_5.JPEG',
#  ('4487081', '6'): './dataset/autobus-n04487081/n04487081_6.JPEG',
#  ('4487081', '7'): './dataset/autobus-n04487081/n04487081_7.JPEG',
#  ('4487081', '8'): './dataset/autobus-n04487081/n04487081_8.JPEG',
#  ('4487081', '9'): './dataset/autobus-n04487081/n04487081_9.JPEG',
#  ('4487081', '10'): './dataset/autobus-n04487081/n04487081_10.JPEG',
#  ('4487081', '11'): './dataset/autobus-n04487081/n04487081_11.JPEG',
#  ('4487081', '12'): './dataset/autobus-n04487081/n04487081_12.JPEG',
#  ('4487081', '13'): './dataset/autobus-n04487081/n04487081_13.JPEG',
#  ('4487081', '14'): './dataset/autobus-n04487081/n04487081_14.JPEG',
#  ('4487081', '15'): './dataset/autobus-n04487081/n04487081_15.JPEG',
#  ('4487081', '16'): './dataset/autobus-n04487081/n04487081_16.JPEG',
#  ('4487081', '17'): './dataset/autobus-n04487081/n04487081_17.JPEG',
#  ('4487081', '18'): './dataset/autobus-n04487081/n04487081_18.JPEG',
#  ('4487081', '19'): './dataset/autobus-n04487081/n04487081_19.JPEG',
#  ('4487081', '20'): './dataset/autobus-n04487081/n04487081_20.JPEG',
#  ('4487081', '21'): './dataset/autobus-n04487081/n04487081_21.JPEG',
#  ('4487081', '22'): './dataset/autobus-n04487081/n04487081_22.JPEG',
#  ('4487081', '23'): './dataset/autobus-n04487081/n04487081_23.JPEG',
#  ('4487081', '24'): './dataset/autobus-n04487081/n04487081_24.JPEG',
#  ('4487081', '25'): './dataset/autobus-n04487081/n04487081_25.JPEG',
#  ('4487081', '26'): './dataset/autobus-n04487081/n04487081_26.JPEG',
#  ('4487081', '27'): './dataset/autobus-n04487081/n04487081_27.JPEG',
#  ('4487081', '28'): './dataset/autobus-n04487081/n04487081_28.JPEG',
#  ('4487081', '29'): './dataset/autobus-n04487081/n04487081_29.JPEG',
#  ('4487081', '30'): './dataset/autobus-n04487081/n04487081_30.JPEG',
#  ('4487081', '71'): './dataset/autobus-n04487081/n04487081_71.JPEG',
#  ('4487081', '72'): './dataset/autobus-n04487081/n04487081_72.JPEG',
#  ('4487081', '73'): './dataset/autobus-n04487081/n04487081_73.JPEG',
#  ('4487081', '74'): './dataset/autobus-n04487081/n04487081_74.JPEG',
#  ('4487081', '75'): './dataset/autobus-n04487081/n04487081_75.JPEG',
#  ('4487081', '76'): './dataset/autobus-n04487081/n04487081_76.JPEG',
#  ('4487081', '77'): './dataset/autobus-n04487081/n04487081_77.JPEG',
#  ('4487081', '78'): './dataset/autobus-n04487081/n04487081_78.JPEG',
#  ('4487081', '79'): './dataset/autobus-n04487081/n04487081_79.JPEG',
#  ('4487081', '80'): './dataset/autobus-n04487081/n04487081_80.JPEG',
#  ('4487081', '81'): './dataset/autobus-n04487081/n04487081_81.JPEG',
#  ('4487081', '82'): './dataset/autobus-n04487081/n04487081_82.JPEG',
#  ('4487081', '83'): './dataset/autobus-n04487081/n04487081_83.JPEG',
#  ('4487081', '84'): './dataset/autobus-n04487081/n04487081_84.JPEG',
#  ('4487081', '85'): './dataset/autobus-n04487081/n04487081_85.JPEG',
#  ('4487081', '86'): './dataset/autobus-n04487081/n04487081_86.JPEG',
#  ('4487081', '87'): './dataset/autobus-n04487081/n04487081_87.JPEG',
#  ('4487081', '88'): './dataset/autobus-n04487081/n04487081_88.JPEG',
#  ('4487081', '89'): './dataset/autobus-n04487081/n04487081_89.JPEG',
#  ('4487081', '90'): './dataset/autobus-n04487081/n04487081_90.JPEG',
#  ('4487081', '91'): './dataset/autobus-n04487081/n04487081_91.JPEG',
#  ('4487081', '92'): './dataset/autobus-n04487081/n04487081_92.JPEG',
#  ('4487081', '93'): './dataset/autobus-n04487081/n04487081_93.JPEG',
#  ('4487081', '94'): './dataset/autobus-n04487081/n04487081_94.JPEG',
#  ('4487081', '95'): './dataset/autobus-n04487081/n04487081_95.JPEG',
#  ('4487081', '96'): './dataset/autobus-n04487081/n04487081_96.JPEG',
#  ('4487081', '97'): './dataset/autobus-n04487081/n04487081_97.JPEG',
#  ('4487081', '98'): './dataset/autobus-n04487081/n04487081_98.JPEG',
#  ('4487081', '99'): './dataset/autobus-n04487081/n04487081_99.JPEG',
#  ('3804744', '0'): './dataset/clavos-n03804744/n03804744_0.JPEG',
#  ('3804744', '1'): './dataset/clavos-n03804744/n03804744_1.JPEG',
#  ('3804744', '2'): './dataset/clavos-n03804744/n03804744_2.JPEG',
#  ('3804744', '3'): './dataset/clavos-n03804744/n03804744_3.JPEG',
#  ('3804744', '4'): './dataset/clavos-n03804744/n03804744_4.JPEG',
#  ('3804744', '5'): './dataset/clavos-n03804744/n03804744_5.JPEG',
#  ('3804744', '6'): './dataset/clavos-n03804744/n03804744_6.JPEG',
#  ('3804744', '7'): './dataset/clavos-n03804744/n03804744_7.JPEG',
#  ('3804744', '8'): './dataset/clavos-n03804744/n03804744_8.JPEG',
#  ('3804744', '9'): './dataset/clavos-n03804744/n03804744_9.JPEG',
#  ('3804744', '10'): './dataset/clavos-n03804744/n03804744_10.JPEG',
#  ('3804744', '51'): './dataset/clavos-n03804744/n03804744_51.JPEG',
#  ('3804744', '52'): './dataset/clavos-n03804744/n03804744_52.JPEG',
#  ('3804744', '53'): './dataset/clavos-n03804744/n03804744_53.JPEG',
#  ('3804744', '54'): './dataset/clavos-n03804744/n03804744_54.JPEG',
#  ('3804744', '55'): './dataset/clavos-n03804744/n03804744_55.JPEG',
#  ('3804744', '56'): './dataset/clavos-n03804744/n03804744_56.JPEG',
#  ('3804744', '57'): './dataset/clavos-n03804744/n03804744_57.JPEG',
#  ('3804744', '58'): './dataset/clavos-n03804744/n03804744_58.JPEG',
#  ('3804744', '59'): './dataset/clavos-n03804744/n03804744_59.JPEG',
#  ('3804744', '60'): './dataset/clavos-n03804744/n03804744_60.JPEG',
#  ('3804744', '61'): './dataset/clavos-n03804744/n03804744_61.JPEG',
#  ('3804744', '62'): './dataset/clavos-n03804744/n03804744_62.JPEG',
#  ('3804744', '63'): './dataset/clavos-n03804744/n03804744_63.JPEG',
#  ('3804744', '64'): './dataset/clavos-n03804744/n03804744_64.JPEG',
#  ('3804744', '65'): './dataset/clavos-n03804744/n03804744_65.JPEG',
#  ('3804744', '66'): './dataset/clavos-n03804744/n03804744_66.JPEG',
#  ('3804744', '67'): './dataset/clavos-n03804744/n03804744_67.JPEG',
#  ('3804744', '68'): './dataset/clavos-n03804744/n03804744_68.JPEG',
#  ('3804744', '69'): './dataset/clavos-n03804744/n03804744_69.JPEG',
#  ('3804744', '70'): './dataset/clavos-n03804744/n03804744_70.JPEG',
#  ('3804744', '71'): './dataset/clavos-n03804744/n03804744_71.JPEG',
#  ('3804744', '72'): './dataset/clavos-n03804744/n03804744_72.JPEG',
#  ('3804744', '73'): './dataset/clavos-n03804744/n03804744_73.JPEG',
#  ('3804744', '74'): './dataset/clavos-n03804744/n03804744_74.JPEG',
#  ('3804744', '75'): './dataset/clavos-n03804744/n03804744_75.JPEG',
#  ('3804744', '76'): './dataset/clavos-n03804744/n03804744_76.JPEG',
#  ('3804744', '77'): './dataset/clavos-n03804744/n03804744_77.JPEG',
#  ('3804744', '78'): './dataset/clavos-n03804744/n03804744_78.JPEG',
#  ('3804744', '79'): './dataset/clavos-n03804744/n03804744_79.JPEG',
#  ('3804744', '80'): './dataset/clavos-n03804744/n03804744_80.JPEG',
#  ('3804744', '81'): './dataset/clavos-n03804744/n03804744_81.JPEG',
#  ('3804744', '82'): './dataset/clavos-n03804744/n03804744_82.JPEG',
#  ('3804744', '83'): './dataset/clavos-n03804744/n03804744_83.JPEG',
#  ('3804744', '84'): './dataset/clavos-n03804744/n03804744_84.JPEG',
#  ('3804744', '85'): './dataset/clavos-n03804744/n03804744_85.JPEG',
#  ('3804744', '86'): './dataset/clavos-n03804744/n03804744_86.JPEG',
#  ('3804744', '87'): './dataset/clavos-n03804744/n03804744_87.JPEG',
#  ('3804744', '88'): './dataset/clavos-n03804744/n03804744_88.JPEG',
#  ('3804744', '89'): './dataset/clavos-n03804744/n03804744_89.JPEG',
#  ('3804744', '90'): './dataset/clavos-n03804744/n03804744_90.JPEG',
#  ('2123394', '63'): './dataset/gatos-n02123394/n02123394_63.JPEG',
#  ('2123394', '64'): './dataset/gatos-n02123394/n02123394_64.JPEG',
#  ('2123394', '65'): './dataset/gatos-n02123394/n02123394_65.JPEG',
#  ('2123394', '66'): './dataset/gatos-n02123394/n02123394_66.JPEG',
#  ('2123394', '67'): './dataset/gatos-n02123394/n02123394_67.JPEG',
#  ('2123394', '68'): './dataset/gatos-n02123394/n02123394_68.JPEG',
#  ('2123394', '69'): './dataset/gatos-n02123394/n02123394_69.JPEG',
#  ('2123394', '70'): './dataset/gatos-n02123394/n02123394_70.JPEG',
#  ('2123394', '71'): './dataset/gatos-n02123394/n02123394_71.JPEG',
#  ('2123394', '72'): './dataset/gatos-n02123394/n02123394_72.JPEG',
#  ('2123394', '73'): './dataset/gatos-n02123394/n02123394_73.JPEG',
#  ('2123394', '74'): './dataset/gatos-n02123394/n02123394_74.JPEG',
#  ('2123394', '75'): './dataset/gatos-n02123394/n02123394_75.JPEG',
#  ('2123394', '76'): './dataset/gatos-n02123394/n02123394_76.JPEG',
#  ('2123394', '77'): './dataset/gatos-n02123394/n02123394_77.JPEG',
#  ('2123394', '78'): './dataset/gatos-n02123394/n02123394_78.JPEG',
#  ('2123394', '79'): './dataset/gatos-n02123394/n02123394_79.JPEG',
#  ('2123394', '80'): './dataset/gatos-n02123394/n02123394_80.JPEG',
#  ('2123394', '81'): './dataset/gatos-n02123394/n02123394_81.JPEG',
#  ('2123394', '82'): './dataset/gatos-n02123394/n02123394_82.JPEG',
#  ('2123394', '83'): './dataset/gatos-n02123394/n02123394_83.JPEG',
#  ('2123394', '84'): './dataset/gatos-n02123394/n02123394_84.JPEG',
#  ('2123394', '85'): './dataset/gatos-n02123394/n02123394_85.JPEG',
#  ('2123394', '86'): './dataset/gatos-n02123394/n02123394_86.JPEG',
#  ('2123394', '87'): './dataset/gatos-n02123394/n02123394_87.JPEG',
#  ('2123394', '88'): './dataset/gatos-n02123394/n02123394_88.JPEG',
#  ('2123394', '89'): './dataset/gatos-n02123394/n02123394_89.JPEG',
# ...
#  ('2480495', '64'): './dataset/mono-n02480495/n02480495_64.JPEG',
#  ('2480495', '65'): './dataset/mono-n02480495/n02480495_65.JPEG',
#  ('2480495', '66'): './dataset/mono-n02480495/n02480495_66.JPEG',
#  ('2480495', '67'): './dataset/mono-n02480495/n02480495_67.JPEG',
#  ('2480495', '68'): './dataset/mono-n02480495/n02480495_68.JPEG',
#  ('2480495', '69'): './dataset/mono-n02480495/n02480495_69.JPEG',
#  ('2480495', '70'): './dataset/mono-n02480495/n02480495_70.JPEG',
#  ('2480495', '71'): './dataset/mono-n02480495/n02480495_71.JPEG',
#  ('2480495', '72'): './dataset/mono-n02480495/n02480495_72.JPEG',
#  ('2480495', '73'): './dataset/mono-n02480495/n02480495_73.JPEG',
#  ('2480495', '74'): './dataset/mono-n02480495/n02480495_74.JPEG',
#  ('2480495', '75'): './dataset/mono-n02480495/n02480495_75.JPEG',
#  ('2480495', '76'): './dataset/mono-n02480495/n02480495_76.JPEG',
#  ('4099969', '80'): './dataset/silla-n04099969/n04099969_80.JPEG',
#  ('4099969', '81'): './dataset/silla-n04099969/n04099969_81.JPEG',
#  ('4099969', '82'): './dataset/silla-n04099969/n04099969_82.JPEG',
#  ('4099969', '83'): './dataset/silla-n04099969/n04099969_83.JPEG',
#  ('4099969', '84'): './dataset/silla-n04099969/n04099969_84.JPEG',
#  ('4099969', '85'): './dataset/silla-n04099969/n04099969_85.JPEG',
#  ('4099969', '86'): './dataset/silla-n04099969/n04099969_86.JPEG',
#  ('4099969', '87'): './dataset/silla-n04099969/n04099969_87.JPEG',
#  ('4099969', '88'): './dataset/silla-n04099969/n04099969_88.JPEG',
#  ('4099969', '89'): './dataset/silla-n04099969/n04099969_89.JPEG',
#  ('4099969', '90'): './dataset/silla-n04099969/n04099969_90.JPEG',
#  ('4099969', '91'): './dataset/silla-n04099969/n04099969_91.JPEG',
#  ('4099969', '92'): './dataset/silla-n04099969/n04099969_92.JPEG',
#  ('4099969', '93'): './dataset/silla-n04099969/n04099969_93.JPEG',
#  ('4099969', '94'): './dataset/silla-n04099969/n04099969_94.JPEG',
#  ('4099969', '95'): './dataset/silla-n04099969/n04099969_95.JPEG',
#  ('4099969', '96'): './dataset/silla-n04099969/n04099969_96.JPEG',
#  ('4099969', '97'): './dataset/silla-n04099969/n04099969_97.JPEG',
#  ('4099969', '98'): './dataset/silla-n04099969/n04099969_98.JPEG',
#  ('4099969', '99'): './dataset/silla-n04099969/n04099969_99.JPEG'}

# %% [markdown]
# # SIFT

# %% [markdown]
# Definimos funciones que nos seran utiles posteriormente

# %%
def get_n_similar(n, counts):
    sorted_counts = sorted(counts.items(), key=lambda x:x[1], reverse=True)[:n] #Ordeno y me quedo con los 5 más parecidos
    sorted_indexes = [idx[0] for idx in sorted_counts]
    return sorted_indexes

def display_n_similar(sorted_indexes, n):
    if n <= 0:
        print("El valor de n debe ser mayor que 0.")
        return

    if n > len(sorted_indexes):
        print(f"Solo hay {len(sorted_indexes)} imágenes en la lista. Mostrando todas.")
        n = len(sorted_indexes)
    fig, axs = plt.subplots(1, n, figsize=(15,15))
    for i in range(n):
        n_carpeta = (sorted_indexes[i][0])
        n_img = (sorted_indexes[i][1])
        print((n_carpeta, n_img))
        path = images_path[(n_carpeta, n_img)]
        im = cv2.cvtColor(cv2.imread(path), cv2.COLOR_BGR2RGB)
        axs[i].imshow(im)
        axs[i].axis('off')

    plt.show()

# %% [markdown]
# Para este proyecto vamos a usar un subconjunto de imagenes de imagenet

# %%
im1 = cv2.imread(list(images_path.values())[0])
im1 = cv2.cvtColor(im1, cv2.COLOR_BGR2RGB)
plt.imshow(im1)
plt.show()
gray_im1 = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY)
plt.imshow(gray_im1, cmap='gray')
plt.show()

# %%
sift = cv2.SIFT_create()

keypoints_1, descriptors_1 = sift.detectAndCompute(gray_im1, mask=None)
im1_sift = cv2.drawKeypoints(gray_im1, keypoints_1, im1, flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

plt.figure(figsize=(10,10))
plt.imshow(im1_sift)
plt.show()

# %% [markdown]
# Creamos una matriz numpy donde almacenaremos todos los descriptores con la etiqueta de la imagen a la q pertenecen

# %%
sift = cv2.SIFT_create()
descriptors = np.empty((0,130))

for idx in images_path:
    gray_im = cv2.cvtColor(cv2.imread(images_path[idx]), cv2.COLOR_BGR2GRAY)
    _, descriptor = sift.detectAndCompute(gray_im, mask=None)

    descriptors_arr = np.array(descriptor)
    descriptors_arr = np.insert(descriptors_arr, 0, idx[1], axis=1)
    descriptors_arr = np.insert(descriptors_arr, 0, idx[0], axis=1)
    descriptors =  np.vstack([descriptors, descriptors_arr]) #Pos 0 -> carpeta, Pos 1 -> numero de imagen

# %% [markdown]
# Entrenamos knn

# %%
from sklearn.neighbors import NearestNeighbors
knn = NearestNeighbors(n_neighbors=5, algorithm='auto', metric='euclidean')

descriptors_train = descriptors[:, 2:] #Quitamos los dos primeros pertenecientes a indices de la imagen
knn.fit(descriptors_train)
# Out:
# NearestNeighbors(metric='euclidean')

# %% [markdown]
# La estrategia para determinar las imagenes mas similares sera la siguiente:
#
# 1.- Obtenemos para cada descriptor de la imagen nueva sus 5 descriptores mas cercanos.
#
# 2.- Obtenemos los ID de las imagenes a las que pertenecen dichos descriptores.
#
# 3.- Almacenamos en un diccionario el numero de veces que aparece un descriptor de cada imagen.
#
# 4.- Recuperamos las n imagenes con mayor numero de descriptores coincidentes con los de la imagen nueva.

# %%
counts = {}
new_image_path = list(images_path.values())[random.randrange(0, len(carpetas)*n_imgs - 1)]
new_img = cv2.cvtColor(cv2.imread(new_image_path), cv2.COLOR_BGR2RGB)
plt.imshow(new_img)
_ , new_descriptors = sift.detectAndCompute(new_img, mask=None)
for descriptor in new_descriptors:
    descriptor = descriptor.reshape(1, -1)
    distance, indice = knn.kneighbors(descriptor, n_neighbors=5)
    for idx in indice[0]:
        carpeta = str(int(descriptors[idx,0]))
        num_img = str(int(descriptors[idx,1]))
        id = (carpeta, num_img)
        if id in counts:
            counts[id] += 1
        else:
            counts[id] = 1

# %%
idx_similar = get_n_similar(5, counts)
display_n_similar(idx_similar, 5)
# Out:
# ('2123394', '21')
# ('2123394', '59')
# ('2123394', '56')
# ('3970156', '66')
# ('2123394', '31')

# %% [markdown]
# ## SIFT2

# %% [markdown]
# Ahora implementaremos otra forma de medir la similaridad entre 2 imagenes. Ahora, en vez de quedarnos con los n vecinos mas cercanos vamos a obtener todos, y de esta forma obtendremos todas las combinaciones posibles entre descriptores y obtendremos sus respectivas distancias.
#
# Una vez tenemos las distancias de cada descriptor de cada imagen procedemos a calcular la media de las distancias, de forma que las imagenes se organizaran segun la media de distancias de sus descriptores.

# %%
from sklearn.neighbors import NearestNeighbors
n_imgs = 100
knn = NearestNeighbors(n_neighbors=n_imgs, algorithm='auto', metric='euclidean')

descriptors_train = descriptors[:, 1:]
knn.fit(descriptors_train)

counts = {}

new_img = cv2.cvtColor(cv2.imread('n04487081_16.JPEG'), cv2.COLOR_BGR2GRAY)
_ , descriptor = sift.detectAndCompute(new_img, mask=None)
descriptors_arr = np.array(descriptor)
for descriptor_i in descriptor:
  descriptor_i = descriptor_i.reshape(1, -1)
  distance, indice = knn.kneighbors(descriptor_i, n_neighbors=n_imgs)

  idx_dist = list(zip(indice[0], distance[0]))

  for tupl in idx_dist:
    id = str(descriptors[tupl[0],0])
    if id in counts:
      counts[id] += [tupl[1]]
    else:
      counts[id] = [tupl[1]]
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[13], line 10
#       6 knn.fit(descriptors_train)
#       8 counts = {}
# ---> 10 new_img = cv2.cvtColor(cv2.imread('n04487081_16.JPEG'), cv2.COLOR_BGR2GRAY)
#      11 _ , descriptor = sift.detectAndCompute(new_img, mask=None)
#      12 descriptors_arr = np.array(descriptor)
#
# error: OpenCV(4.6.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
from statistics import mean
avg_distances = {clave: mean(valores) for clave, valores in counts.items()}
im1 = cv2.imread('n04487081_16.JPEG')
im1 = cv2.cvtColor(im1, cv2.COLOR_BGR2RGB)
sorted_indexes = get_n_similar(5)
display_n_similar(sorted_indexes, 8)

# %% [markdown]
# # CNN

# %%
from keras.applications import VGG16
from keras.models import Model
from keras.applications.vgg16 import preprocess_input

base_model = VGG16(weights='imagenet', include_top=False)
model = Model(inputs=base_model.input, outputs=base_model.layers[-1].output)

# %%
if os.path.exists('CNN_matrix.npy'):
    caracteristics = np.load('CNN_matrix.npy')
else:
    caracteristics = np.empty((0,25090))
    for idx in images_path:
        im = cv2.cvtColor(cv2.imread(images_path[idx]), cv2.COLOR_BGR2RGB)
        # Redimensionar la imagen al tamaño requerido por el modelo
        target_size = (224, 224)
        im = cv2.resize(im, target_size)
        # Agregar una dimensión
        im = np.expand_dims(im, axis=0)
        # Normalizar la imagen
        im = preprocess_input(im)

        # Extraer las características de la imagen
        caracteristics_img = model.predict(im, verbose=0)
        caracteristics_flat = caracteristics_img.reshape(1, -1)
        caracteristics_flat = np.insert(caracteristics_flat, 0, idx[1], axis=1)
        caracteristics_flat = np.insert(caracteristics_flat, 0, idx[0], axis=1)
        caracteristics =  np.vstack([caracteristics, caracteristics_flat])
    np.save('CNN_matrix', caracteristics)

# %%
from sklearn.neighbors import NearestNeighbors
knn = NearestNeighbors(n_neighbors=5, algorithm='auto', metric='euclidean')

caracteristics_train = caracteristics[:, 2:]
knn.fit(caracteristics_train)
# Out:
# NearestNeighbors(metric='euclidean')

# %%
new_image_path = list(images_path.values())[random.randrange(0, len(carpetas)*n_imgs - 1)]
new_img = cv2.cvtColor(cv2.imread(new_image_path), cv2.COLOR_BGR2RGB)
plt.imshow(new_img)
# Redimensionar la imagen al tamaño requerido por el modelo
target_size = (224, 224)
new_img = cv2.resize(new_img, target_size)
# Agregar una dimensión
new_img = np.expand_dims(new_img, axis=0)
# Normalizar la imagen
new_img = preprocess_input(new_img)

# Extraer las características de la imagen
caracteristics_img = model.predict(new_img)
caracteristics_flat = caracteristics_img.reshape(1, -1)
distance, indice = knn.kneighbors(caracteristics_flat, n_neighbors=5)

ids = []
for idx in indice[0]:
        carpeta = str(int(caracteristics[idx,0]))
        num_img = str(int(caracteristics[idx,1]))
        ids.append((carpeta, num_img))
# Out:
# 1/1 [==============================] - 0s 229ms/step

# %%
display_n_similar(ids, 5)
# Out:
# ('4532670', '66')
# ('4532670', '43')
# ('4532670', '89')
# ('1917289', '23')
# ('3804744', '69')
